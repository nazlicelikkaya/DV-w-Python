# %% [markdown]
# ___
#
# <a href="https://lms.clarusway.com/course/view.php?id=7435"><img align="center" src="https://i.ibb.co/6Z5pQxD/lmss.png" alt="Open in Clarusway LMS" width="70" height="200" title="Open Clarusway Learning Management Sytem"></a>
#
# ___
#
# <a href="https://clarusway.com/"><img align="center" src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" alt="CLRSWY" width="450" height="200" title="Welcome to Place Where You can Reinvent Yourself"></a><br/>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:120%; text-align:center; border-radius:10px 10px;">Way to Reinvent Yourself</p>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/99DQ3TY/DS-Courses.png" class="img-fluid"
# alt="CLRSWY"></p>
#
#
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">POLICE KILLING US - SEABORN VISUALiZATION TASK</p>
#
# <img src=https://i.ibb.co/z8vpsJM/police-killing-us.png width="700" height="200">
#
# [Photo Credit: Wikipedia](https://en.wikipedia.org/wiki/Lists_of_killings_by_law_enforcement_officers_in_the_United_States#cite_note-1)
#
#
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Visualization with Python</p>
#
# ![Image_Assignment](https://i.ibb.co/cY9HhF7/bnote-assignment.gif)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#4d77cf; font-size:150%; text-align:center; border-radius:10px 10px;">Assignment 02 (PoliceKillingUS-Seaborn)</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">CONTENT</p>
#
# * [ABOUT THE DATASET & CONTEXT](#00)
# * [ABOUT THE FEATURES](#000)
# * [IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK](#0)
# * [INSTRUCTIONS (Tasks in the Assignment)](#1)
# * [TASK-01 PLOT AGE BY GENDER IN TERMS OF MANNER OF DEATH](#2)
#     * [1.1 Box plot of age in both genders separeted by manner of death](#2.1)
#     * [1.2 Box plot of age in both genders separeted by manner of death](#2.2)
# * [TASK-02 PLOT 12 MOST DANGEROUS CITIES](#3)
# * [TASK-03 PLOT 20 MOST DANGEROUS STATES](#4)
# * [TASK-04 PLOT THE KILLED PEOPLE HAVING MENTAL-ILLNESS OR NOT](#5)
# * [TASK-05 PLOT THE NUMBER OF THREAT TYPES](#6)
# * [TASK-06 PLOT THE NUMBER OF FLEE TYPES](#7)
# * [THE END OF THE ASSIGNMENT-02](#8)

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">ABOUT THE DATASET & CONTEXT</p>
#
# "In 2015, The Washington Post began to log [every fatal shooting](https://www.washingtonpost.com/graphics/national/police-shootings-year-end/) by an on-duty police officer in the United States. In that time there have been [more than 5,000 such shootings](https://www.washingtonpost.com/nation/2019/08/09/what-weve-learned-about-police-shootings-years-after-ferguson/?arc404=true) recorded by The Post. After [Michael Brown, an unarmed Black man, was killed](https://www.washingtonpost.com/policeshootings/) in 2014 by police in Ferguson, Mo., a Post investigation found that the [FBI undercounted fatal police shootings](https://www.washingtonpost.com/news/post-nation/wp/2014/09/08/how-many-police-shootings-a-year-no-one-knows/) by more than half. This is because reporting by police departments is voluntary and many departments fail to do so. The Washington Post’s data relies primarily on news accounts, social media postings and police reports. Analysis of more than five years of data reveals that the number and circumstances of fatal shootings and the overall demographics of the victims have remained relatively constant..." [SOURCE ==> Washington Post Article](https://www.washingtonpost.com/graphics/investigations/police-shootings-database/)
#
# [For more information about this story](https://www.washingtonpost.com/graphics/investigations/police-shootings-database/)
#
#
# This dataset has been prepared by The Washington Post (they keep updating it on runtime) with every fatal shooting in the United States by a police officer in the line of duty since Jan. 1, 2015.
#
# [2016 PoliceKillingUS DATASET](https://www.washingtonpost.com/graphics/national/police-shootings-2016/)<br>
# [2017 PoliceKillingUS DATASET](https://www.washingtonpost.com/graphics/national/police-shootings-2017/)<br>
# [2018 PoliceKillingUS DATASET](https://www.washingtonpost.com/graphics/2018/national/police-shootings-2018/)<br>
# [2019 PoliceKillingUS DATASET](https://www.washingtonpost.com/graphics/2019/national/police-shootings-2019/)<br>
# [2020 PoliceKillingUS DATASET](https://www.washingtonpost.com/graphics/national/police-shootings-2017/)<br>
#
#
# **In this assignment, you are supposed to do the exercise yourself to see if you can solve it. While solving the tasks if you need to remember some subjects, please repeat inclass materails in the course and udemy course videos if provided to you.**

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">ABOUT THE FEATURES</p>
#
# <a id="00"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# The file fatal-police-shootings-data.csv contains data about each fatal shooting in CSV format. The file can be downloaded at this URL. Each row has the following variables:
#
# - **id:** a unique identifier for each victim
# - **name:** the name of the victim
# - **date:** the date of the fatal shooting in YYYY-MM-DD format
# - **manner_of_death:** shot, shot and Tasered
# - **armed:** indicates that the victim was armed with some sort of implement that a police officer believed could inflict harm
#     - undetermined: it is not known whether or not the victim had a weapon
#     - unknown: the victim was armed, but it is not known what the object was
#     - unarmed: the victim was not armed
# - **age:** the age of the victim
# - **gender:** the gender of the victim. The Post identifies victims by the gender they identify with if reports indicate that it differs from their biological sex.
#     - M: Male
#     - F: Female
#     - None: unknown
# - **race:**
#     - W: White, non-Hispanic
#     - B: Black, non-Hispanic
#     - A: Asian
#     - N: Native American
#     - H: Hispanic
#     - O: Other
#     - None: unknown
# - **city:** the municipality where the fatal shooting took place. Note that in some cases this field may contain a county name if a more specific municipality is unavailable or unknown.
# - **state:** two-letter postal code abbreviation
# - **signs of mental illness:** News reports have indicated the victim had a history of mental health issues, expressed suicidal intentions or was experiencing mental distress at the time of the shooting.
# - **threat_level:** The threat_level column was used to flag incidents for the story by Amy Brittain in October 2015. http://www.washingtonpost.com/sf/investigative/2015/10/24/on-duty-under-fire/ As described in the story, the general criteria for the attack label was that there was the most direct and immediate threat to life. That would include incidents where officers or others were shot at, threatened with a gun, attacked with other weapons or physical force, etc. The attack category is meant to flag the highest level of threat. The other and undetermined categories represent all remaining cases. Other includes many incidents where officers or others faced significant threats.
# - **flee:** News reports have indicated the victim was moving away from officers
#     - Foot
#     - Car
#     - Not fleeing
#
# The threat column and the fleeing column are not necessarily related. For example, there is an incident in which the suspect is fleeing and at the same time turns to fire at gun at the officer. Also, attacks represent a status immediately before fatal shots by police while fleeing could begin slightly earlier and involve a chase.
# - **body_camera:** News reports have indicated an officer was wearing a body camera and it may have recorded some portion of the incident.
#
# [SOURCE](https://github.com/washingtonpost/data-police-shootings)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK</p>
#
# <a id="000"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
import numpy as np 
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from collections import Counter

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">INSTRUCTIONS (Tasks in the Assignment)</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# **In this assignment you're required to handle with the following tasks:**
#
# - **Task 1.** Using Box and Swarm Plots, plotting Age by Gender in terms of "Manner of Death" column of DataFrame named as "kill"<br>
# - **Task 2.** Plotting Most dangerous cities<br>
# - **Task 3.** Plotting Most dangerous states<br>
# - **Task 4.** Plotting the killed people having mental illness or not<br>
# - **Task 5.** Plotting threat types<br>
# - **Task 6.** Plotting flee types<br>
#
# Before diving into the tasks in the assignment, you have to read the dataset. If you have some obatacles while reading the dataset, we recommend you make a research on 🤔 "how to read the dataset in Pandas" and 🧐 play with the parameters inside the pandas.read_csv() method. You can use encoding="windows-1252" parameter for reading this dataset.
#
# ⚠️ In this assignment you are supposed to make some visualizations according to the following questions. So, unless otherwise stated, you do NOT need to follow any Exploratory Data Analysis steps, such as handling missing values & outliers, dropping duplicates, and etc., or apply any Pandas method for preparing the dataset to Machine Learning modelling ⚠️
#
# **Now Let us first try to load and read the PoliceKillingsUS dataset. [SOURCE](https://towardsdatascience.com/learn-how-to-read-data-into-a-pandas-dataframe-in-5-minutes-122af8e0b9db) for learning how to read data into a Pandas DataFrame in 5 minutes.**

# %%
# Reading and assigning the data to an object named "kill"

kill = pd.read_csv('PoliceKillingsUS.csv', encoding="windows-1252")

# %%
kill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2254 entries, 0 to 2534
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2254 non-null   int64
#  1   name                     2254 non-null   object
#  2   date                     2254 non-null   object
#  3   manner_of_death          2254 non-null   object
#  4   armed                    2254 non-null   object
#  5   age                      2254 non-null   float64
#  6   gender                   2254 non-null   object
#  7   race                     2254 non-null   object
#  8   city                     2254 non-null   object
#  9   state                    2254 non-null   object
#  10  signs_of_mental_illness  2254 non-null   bool
#  11  threat_level             2254 non-null   object
#  12  flee                     2254 non-null   object
#  13  body_camera              2254 non-null   bool
# ...

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.shape
# Out:
# (2535, 14)

# %%
kill.isnull().sum()
# Out:
# id                           0
# name                         0
# date                         0
# manner_of_death              0
# armed                        9
# age                         77
# gender                       0
# race                       195
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                        65
# body_camera                  0
# dtype: int64

# %% [markdown]
# **Since our purpose is not a comprehensive analysis, we will drop null values ​​to practice visualization using the seaborn library.**

# %%
# Let's drop the null values in the dataset

kill.dropna(inplace=True)

# %%
kill.shape
# Out:
# (2254, 14)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task-01: Plot Age by Gender in terms of "Manner of Death"</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# **We will see 3 different features in our plot: "age", "gender" and "manner of death"**

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:125%; text-align:left; border-radius:10px 10px;">1.1 Box plot of age in both genders separeted by manner of death.</p>
#
# <a id="2.1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# **Let's look at an "info" before applying the head method. Take a picture of our data and take an overview of our DataFrame and its Features.**

# %%
print(kill.info())
kill.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2254 entries, 0 to 2534
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2254 non-null   int64
#  1   name                     2254 non-null   object
#  2   date                     2254 non-null   object
#  3   manner_of_death          2254 non-null   object
#  4   armed                    2254 non-null   object
#  5   age                      2254 non-null   float64
#  6   gender                   2254 non-null   object
#  7   race                     2254 non-null   object
#  8   city                     2254 non-null   object
#  9   state                    2254 non-null   object
#  10  signs_of_mental_illness  2254 non-null   bool
#  11  threat_level             2254 non-null   object
#  12  flee                     2254 non-null   object
#  13  body_camera              2254 non-null   bool
# ...

# %%
kill.sample(10)
# Out:
#         id                    name      date   manner_of_death         armed  \
# 364    465           David  Gaines  19/05/15              shot           gun
# 1231  1412              Jose Perez  26/03/16              shot  meat cleaver
# 1077  1235         Raymond Gassman  03/02/16              shot           gun
# 1108  1268  Ali Eisa Abdalla Yahia  13/02/16  shot and Tasered           gun
# 271    335  Angel Cresencio Corona  10/04/15              shot         knife
# 1610  1801          Trenton Lohman  18/08/16              shot           gun
# 777    917         Kaleb Alexander  15/10/15              shot           gun
# 510    632            David Lepine  12/07/15              shot           gun
# 2110  2364           Jesse Enjaian  17/02/17              shot           gun
# 1545  1735            Devon Martes  27/07/16              shot           gun
#
#        age gender race            city state  signs_of_mental_illness  \
# ...

# %% [markdown]
# **Random lines from sample can give me more information about the data than the first 5 lines from head will.**

# %%
kill.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %% [markdown]
# **When we want to see the quartiles, we use box plot. But first, let's have an idea about the distribution of our data**

# %%
sns.kdeplot(kill.age);

# %% [markdown]
# **By looking at the relative magnitudes of the "mean" and "median" values, we can get an idea of the skewness status of a feature.**
#
# **A "right skewed" distribution exists when "mean" is significantly greater than "median". However, if the "mean" is significantly smaller than the "median", there is a "left skewed" distribution.**

# %%
kill.age.describe()
# Out:
# count    2254.000000
# mean       36.254215
# std        12.838671
# min         6.000000
# 25%        26.000000
# 50%        34.000000
# 75%        45.000000
# max        91.000000
# Name: age, dtype: float64

# %%
kill.age.median()
# Out:
# 34.0

# %%
kill.age.mean()
# Out:
# 36.254214729370005

# %% [markdown]
# **We can have an idea about skewness by looking at the extreme values in boxplot. Where the majority of extreme values are, there is a possible skewness on that side..**

# %%
sns.boxplot(kill.age)
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# **We can also get an idea of skewness by looking at the appearance of a histogram plot.**

# %%
sns.histplot(kill.age)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %% [markdown]
# **Pandas always helps us more than other modules when it comes to data analysis.**

# %%
# Pandas' skew() method.

kill.skew(skipna=True)
# Out:
# id                         0.054169
# age                        0.708701
# signs_of_mental_illness    1.129712
# body_camera                2.465443
# dtype: float64

# %% [markdown]
# **we make use of a "boolean" feature by using it as a categorical variable inside the barplot**

# %%
fig, ax = plt.subplots(figsize=(10, 6)) 
ax = sns.boxplot(x="body_camera", y = "age", data=kill)
ax.yaxis.grid(True);

# %% [markdown]
# **When you want to hide one of the labels that come automatically when you use Seaborn, you can assign an empty string to that label.**

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax = sns.boxplot(x="body_camera", y="age", data=kill)

ax.set(ylabel="")

plt.title("Age by body_camera")

# ax.yaxis.grid(True)
# Out:
# Text(0.5, 1.0, 'Age by body_camera')

# %% [markdown]
# **Let's solve our task now:**

# %%
fig, ax = plt.subplots(figsize=(10,6))

# plt.figure(figsize=(12,6))

sns.boxplot(x = kill.gender, y=kill.age, hue = kill["manner_of_death"])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.boxplot(data=kill, x = kill.gender, y=kill.age, hue = "manner_of_death")

# Let's get legend out:
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0);

# %% [markdown]
# Desired Output:
#
# <img src=https://i.ibb.co/yFZXX8J/DV2-1b.png width="700" height="200">

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:125%; text-align:left; border-radius:10px 10px;">1.2 Swarm Plot of age in both genders separeted by manner of death.</p>
#
# <a id="2.2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
# With Seaborn Swarmplot

# YOUR CODE IS HERE
sns.swarmplot(data=kill, x = kill.gender, y=kill.age, hue = "manner_of_death");

# %% [markdown]
# **swarmplot plots for each observation. So this will take a little more time depending on the speed of your processor, the number of cores.**

# %%
# change the order of categorical values and let's spice up "axess" and "figure" a bit.

fig, ax = plt.subplots(figsize=(10,6))

sns.swarmplot(data=kill, 
              x = kill.gender, 
              y=kill.age, 
              hue = "manner_of_death",
             order=["F", "M"],  # change the order of categorical values.
             size= 9);

ax.yaxis.grid(True)
ax.set(facecolor = "thistle")
fig.set_facecolor("powderblue")
plt.title("Age by Gender", 
         fontsize = 20, 
         fontdict = {"color" : "darkred"});

# %% [markdown]
# Desired Output:
#
# <img src=https://i.ibb.co/w4fg9WR/DV2-1c.png width="600" height="200">

# %% [markdown]
# ## BONUS

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.violinplot(x="gender", y="age", data=kill,
              inner="quartile")

ax.set(facecolor = "thistle")

fig.set_facecolor("powderblue")

plt.title("Age by Gender", 
         fontsize = 20, 
         fontdict = {"color" : "darkred"});

# %%
kill.groupby("gender")["age"].apply(lambda x : pd.Series.mode(x)[0])
# Out:
# (gender
#  F    25.0
#  M    25.0
#  Name: age, dtype: float64,)

# %%
Means = kill.groupby("gender")["age"].mean()
Medians = kill.groupby("gender")["age"].median()
Modes = kill.groupby("gender")["age"].apply(lambda x : pd.Series.mode(x)[0])

print("means", Means, sep ="/", end = "\n\n")
print("medians", Medians, sep ="/", end = "\n\n")
print("modes", Modes, sep ="/", end = "\n\n")
# Out:
# means/gender
# F    36.202128
# M    36.256481
# Name: age, dtype: float64
#
# medians/gender
# F    36.0
# M    34.0
# Name: age, dtype: float64
#
# modes/gender
# F    25.0
# M    25.0
# Name: age, dtype: float64

# %%
len(Means)
# Out:
# 2

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.violinplot(x="gender", y="age", data=kill, inner=None)

sns.scatterplot(x=range(len(Means)), y=Means, color="r")
sns.scatterplot(x=range(len(Medians)), y=Medians, color="m")
sns.scatterplot(x=range(len(Modes)), y=Modes, color="black")


ax.axhline(y=Means[0], xmin=0, xmax=0.45, c="red")
ax.axhline(y=Medians[0], xmin=0, xmax=0.45, c="red")
ax.axhline(y=Modes[0], xmin=0, xmax=0.45, c="red")

ax.axhline(y=Means[1], xmin=0.5, xmax=1, c="black")
ax.axhline(y=Medians[1], xmin=0.5, xmax=1, c="black")
ax.axhline(y=Modes[1], xmin=0.5, xmax=1, c="black")

ax.set(facecolor = "thistle")
fig.set_facecolor("powderblue")
plt.title("Age by Gender", 
         fontsize = 20, 
         fontdict = {"color" : "darkred"});

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task-02: Plot Most Dangerous Cities</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# **In your business life, no one will tell you to draw a barplot of two features.
# You decide to use it.**

# %%
city_freq = kill["city"].value_counts()[:12]
city_freq
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Tucson           14
# Name: city, dtype: int64

# %%
city_freq.index
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Austin', 'Las Vegas',
#        'Columbus', 'Miami', 'San Antonio', 'Indianapolis', 'St. Louis',
#        'Bakersfield'],
#       dtype='object')

# %%
city_freq.values
# Out:
# array([35, 28, 24, 22, 18, 17, 16, 15, 15, 14, 14, 13], dtype=int64)

# %%
# with seaborn barplot

fig, ax = plt.subplots(figsize=(8,5))

sns.barplot(x=city_freq.index, y = city_freq.values)

ax.set_xticklabels(city_freq.index, rotation=45)
ax.set_title("Most dangerous cities", 
             color="blue",
             fontsize =15,
             pad=15)

ax.set(facecolor="black")
fig.set_facecolor("powderblue");

# %% [markdown]
# **The parameters used in the dictionary structure  like "fontdict" are very useful.**

# %%
fig, ax =plt.subplots(figsize=(8, 5))
sns.countplot(x="city", data=kill,
             order=city_freq.index)

ax.set_xticklabels(city_freq.index, rotation = -45) # minus 45! 

ax.set_title('Most dangerous cities',   
             loc = "left", 
            fontdict = {'fontsize': 18,   
                    'fontweight': "bold",
                    'color' : "darkred"})

ax.set(facecolor = "black") 
fig.set_facecolor('powderblue')

# %%
kill.city.value_counts().count()
# Out:
# 1417

# %%
kill.city.nunique()
# Out:
# 1417

# %%
city_freq.index
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Las Vegas',
#        'San Antonio', 'Columbus', 'Austin', 'Miami', 'St. Louis',
#        'Oklahoma City', 'Tucson'],
#       dtype='object')

# %%
# With Seaborn Countplot

# without order parameter!! 

fig, ax =plt.subplots(figsize=(8, 5))

sns.countplot(x="city", data=kill)

ax.set_xticklabels(kill.city.unique(), rotation = 45) 

ax.set_title('Most dangerous cities',   
             loc = "left", 
            fontdict = {'fontsize': 18, 
                    'fontweight': "bold", 
                    'color' : "darkred"})
            

ax.set(facecolor = "black") 
fig.set_facecolor('powderblue')

# %%
city_freq
# Out:
# Los Angeles      39
# Phoenix          31
# Houston          27
# Chicago          25
# Las Vegas        21
# San Antonio      20
# Columbus         19
# Austin           18
# Miami            18
# St. Louis        15
# Oklahoma City    14
# Tucson           14
# Name: city, dtype: int64

# %%
city_freq.index
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Las Vegas',
#        'San Antonio', 'Columbus', 'Austin', 'Miami', 'St. Louis',
#        'Oklahoma City', 'Tucson'],
#       dtype='object')

# %%
# with "order" parameter!!

fig, ax =plt.subplots(figsize=(8, 5))

sns.countplot(x="city", 
              data=kill,
             
             order = city_freq.index)  # use the first 12 cities
    
ax.set_xticklabels(city_freq.index, rotation = 45) # To rotate labels

ax.set_title('Most dangerous cities',   
             loc = "left", 
            fontdict = {'fontsize': 18, 
                    'fontweight': "bold",
                    'color' : "darkred"})

ax.set(facecolor = "black") 
fig.set_facecolor('powderblue')

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task-03: Plot 20 Most Dangerous States</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
state_freq = kill.state.value_counts()[:20]
state_freq
# Out:
# CA    366
# TX    200
# FL    136
# AZ    105
# OH     70
# NC     66
# OK     65
# CO     63
# GA     61
# MO     58
# TN     56
# IL     56
# WA     51
# LA     47
# AL     45
# PA     45
# NY     43
# VA     43
# WI     42
# NM     41
# Name: state, dtype: int64

# %%
# with seaborn barplot

fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.barplot(x=state_freq.index, y=state_freq.values)

ax.set_xticklabels(state_freq.index, rotation=45)
ax.set_title('Most dangerous states', color='blue', fontsize=15);

# %%
# with seaborn countplot

fig, ax = plt.subplots(figsize=(8, 5))

sns.countplot(x="state", 
              data=kill,
              order=state_freq.index)

ax.set_xticklabels(state_freq.index, rotation=45)
ax.set_title('Most dangerous states', color='blue', fontsize=15);

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task-04: Plot the Killed People Having Mental-Illness or Not</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
illness= kill['signs_of_mental_illness'].value_counts()
illness
# Out:
# False    1681
# True      573
# Name: signs_of_mental_illness, dtype: int64

# %%
# With Seaborn Barplot

fig, ax = plt.subplots(figsize=(8,6))

ax.set(facecolor = "lavender") 
fig.set_facecolor('powderblue')

sns.barplot(x = illness.index,  y = illness.values)

ax.set_xlabel("signs_of_mental_illness")
ax.set_ylabel("count")

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.35, p.get_height()+20));

# %%
# As of matplotlib v3.4.2
# Use matplotlib.pyplot.bar_label

# To learn which version of matplotlib
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
# Out:
# matplotlib: 3.5.1

# %%
# With Seaborn Barplot

fig, ax = plt.subplots(figsize=(8,6))

ax.set(facecolor = "lavender") 
fig.set_facecolor('powderblue')

sns.barplot(x = illness.index,  y = illness.values)

ax.set_xlabel("signs_of_mental_illness")
ax.set_ylabel("count")

ax.bar_label(ax.containers[0], color="red", 
             size=12);

# %%
# With Seaborn Countplot

fig, ax = plt.subplots(figsize=(8,6), 
                       facecolor="powderblue") 

sns.countplot(kill.signs_of_mental_illness)
              
ax.bar_label(ax.containers[0], color="darkred", 
             size=12);

# or:
# for p in ax.patches:
#     ax.annotate((p.get_height()), (p.get_x()+0.35, p.get_height()+20));

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task-05: Plot the Number of Threat Types</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
kill.columns
# Out:
# Index(['id', 'name', 'date', 'manner_of_death', 'armed', 'age', 'gender',
#        'race', 'city', 'state', 'signs_of_mental_illness', 'threat_level',
#        'flee', 'body_camera'],
#       dtype='object')

# %%
threads_freq = kill['threat_level'].value_counts()
threads_freq
# Out:
# attack          1462
# other            677
# undetermined     115
# Name: threat_level, dtype: int64

# %%
# With Seaborn Countplot

fig, ax = plt.subplots(dpi = 120)  # set the size of the figure with the "dpi" parameter

sns.countplot(kill.threat_level)

ax.bar_label(ax.containers[0], color="darkred", 
             size=10);

# %%
# with Seaborn catplot:

sns.catplot(x="threat_level",
           data=kill,
           kind="count");

# %% [markdown]
# **Let's do a catplot example over the "race" column :**

# %%
sns.catplot(x="race", 
            kind="count", 
            data=kill,
            height=5,
            aspect=1.5)

plt.xlabel("Race Categories", size=14)
plt.ylabel("Number of Kill", size=14)
plt.title("Seaborn countplot example with catplot() function", size=18)
plt.tight_layout()

# %% [markdown]
# **You can save this plot as a "jpg" file in your working directory with the savefig() function.**

# %%
sns.catplot(x="race", 
            kind="count", 
            data=kill,
            height=5,
            aspect=1.5)

plt.xlabel("Race Categories", size=14)
plt.ylabel("Number of Kill", size=14)
plt.title("Seaborn countplot example with catplot() function", size=18)
plt.tight_layout()

plt.savefig("Seaborn_countplot_with_catplot_without ordering_bars.jpg")

# %% [markdown]
# ## BONUS
#
# **More Sources**
#
# [Seaborn: countplot() with frequencies](https://stackoverflow.com/questions/33179122/seaborn-countplot-with-frequencies)<br>
# [Seaborn Barplot - Displaying Values](https://stackoverflow.com/questions/43214978/seaborn-barplot-displaying-values)<br>[How to get the label values on a bar chat with seaborn on a categorical data](https://stackoverflow.com/questions/68320207/how-to-get-the-label-values-on-a-bar-chat-with-seaborn-on-a-categorical-data/68322925#68322925)<br>

# %%
kill.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
threat = kill.threat_level.value_counts()
threat
# Out:
# attack          1611
# other            766
# undetermined     158
# Name: threat_level, dtype: int64

# %%
d = {'attack': 1, 'undetermined': 2, 'other': 3}
kill["threat_type"] = kill["threat_level"].map(d)
kill.head(3)
# Out:
#    id                name      date   manner_of_death    armed   age gender  \
# 0   3          Tim Elliot  02/01/15              shot      gun  53.0      M
# 1   4    Lewis Lee Lembke  02/01/15              shot      gun  47.0      M
# 2   5  John Paul Quintero  03/01/15  shot and Tasered  unarmed  23.0      M
#
#   race     city state  signs_of_mental_illness threat_level         flee  \
# 0    A  Shelton    WA                     True       attack  Not fleeing
# 1    W    Aloha    OR                    False       attack  Not fleeing
# 2    H  Wichita    KS                    False        other  Not fleeing
#
#    body_camera  threat_type
# 0        False            1
# 1        False            1
# 2        False            3

# %%
kill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2535 entries, 0 to 2534
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2535 non-null   int64
#  1   name                     2535 non-null   object
#  2   date                     2535 non-null   object
#  3   manner_of_death          2535 non-null   object
#  4   armed                    2526 non-null   object
#  5   age                      2458 non-null   float64
#  6   gender                   2535 non-null   object
#  7   race                     2340 non-null   object
#  8   city                     2535 non-null   object
#  9   state                    2535 non-null   object
#  10  signs_of_mental_illness  2535 non-null   bool
#  11  threat_level             2535 non-null   object
#  12  flee                     2470 non-null   object
#  13  body_camera              2535 non-null   bool
# ...

# %%
kill['threat_type'].value_counts()
# Out:
# 1    1611
# 3     766
# 2     158
# Name: threat_type, dtype: int64

# %%
kill['threat_type'].value_counts(normalize=True)*100
# Out:
# 1    63.550296
# 3    30.216963
# 2     6.232742
# Name: threat_type, dtype: float64

# %%
fig, ax = plt.subplots()

sns.barplot(x=kill['threat_type'], 
            y=kill['threat_type'], 
            estimator=lambda x: len(x) / len(kill)*100, order=[1, 3, 2])


ax.bar_label(ax.containers[0], fmt='%.1f%%')
ax.set_ylabel('%');

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task-06: Plot the Number of Flee Types</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
flee_freq = kill.flee.value_counts()
flee_freq
# Out:
# Not fleeing    1528
# Car             360
# Foot            278
# Other            88
# Name: flee, dtype: int64

# %%
# with seaborn

sns.countplot(kill.flee);
# Out:
# <AxesSubplot:xlabel='flee', ylabel='count'>

# %%
fig, ax = plt.subplots()

sns.countplot(kill.flee)

for container in ax.containers:
    ax.bar_label(container);

# %%
# OR:

ax = sns.countplot(kill.flee)

ax.bar_label(ax.containers[0], 
             color="darkred");

# %% [markdown]
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">THE END OF THE ASSIGNMENT-02</p>
#
# # Now. it's time to relax! Take your time and sip your coffee
#
# <img src=https://i.ibb.co/jZD3Mqb/relaxing.jpg width="800" height="200">
#
#
# <p style="text-align: center;"><img src="https://i.ibb.co/99DQ3TY/DS-Courses.png" class="img-fluid"
# alt="CLRSWY"></p>
#
# <a href="https://clarusway.com/"><img align="center" src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" alt="CLRSWY" title="Way to Reinvent Yourself"></a><br/>
#
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:120%; text-align:center; border-radius:10px 10px;">Way to Reinvent Yourself</p>
# ___
